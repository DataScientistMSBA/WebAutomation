# %% [markdown]
# <a href="https://colab.research.google.com/github/DataScientistMSBA/WebAutomation/blob/main/Projects/Financial/ETF_MF_Holdings_Allocations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Install packages**

# %%
def PreLoads():
  global clear_output, time, clear_output, webdriver, By, read_html, pd, sys
  from IPython.display import clear_output
  # !pip install selenium
  # !apt-get update # to update ubuntu to correctly run apt install
  # !apt install chromium-chromedriver
  # !cp /usr/lib/chromium-browser/chromedriver /usr/bin
  import time 
  from selenium import webdriver
  from selenium.webdriver.common.by import By
  from pandas.io.html import read_html
  import pandas as pd
  import sys
PreLoads()

time.sleep(1)
clear_output(wait=True)
print('PreLoads processed')
# Out:
# PreLoads processed

# %%
def get_etf_holdings(ticker):
  sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
  options = webdriver.ChromeOptions()
  options.add_argument('--headless')
  options.add_argument('--no-sandbox')
  options.add_argument('--disable-dev-shm-usage')
  driver = webdriver.Chrome('chromedriver',options=options)
  driver.get(f'https://www.morningstar.com/etfs/arcx/{ticker}/portfolio')

  # Header = driver.find_element(by=By.XPATH, value = '''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[1]/header/div/div[1]/h1/span''').text
  # table = driver.find_element(by=By.XPATH, value = '''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody''')
  # table.text.split('\n')[0]

  BackwardButton = driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[2]/div/div/div[1]/div/div[1]/div[2]/div/button[1]''')
  ForwardButton = driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[2]/div/div/div[1]/div/div[1]/div[2]/div/button[2]''')

  CompanyList = []; PortfolioWeightList = []; FirstBoughtList = []; MarketValueList = []; OneYearReturn = []; PEList = []; SectorList = []; ESGRiskRatingAssessmentList = []

  company = 1
  while company <= 10:
    CompanyList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[1]''').text))
    PortfolioWeightList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[2]''').text))
    FirstBoughtList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[3]''').text))
    MarketValueList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[4]''').text))
    OneYearReturn.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[5]''').text))
    PEList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[6]''').text))
    # ESGRiskRatingAssessmentList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[9]''').text))
    SectorList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[10]''').text))
    company += 1
  ForwardButton.click()

  company = 1
  while company <= 10:
    CompanyList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[1]''').text))
    PortfolioWeightList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[2]''').text))
    FirstBoughtList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[3]''').text))
    MarketValueList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[4]''').text))
    OneYearReturn.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[5]''').text))
    PEList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[6]''').text))
    # ESGRiskRatingAssessmentList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[9]''').text))
    SectorList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[10]''').text))
    company += 1
  ForwardButton.click()

  company = 1
  while company <= 5:
    CompanyList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[1]''').text))
    PortfolioWeightList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[2]''').text))
    FirstBoughtList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[3]''').text))
    MarketValueList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[4]''').text))
    OneYearReturn.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[5]''').text))
    PEList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[6]''').text))
    # ESGRiskRatingAssessmentList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[9]''').text))
    SectorList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/div[2]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[10]''').text))
    company += 1

  Holdings = pd.DataFrame(
      {'Holdings': CompanyList,
      '% Portfolio Weight': PortfolioWeightList,
      'First Bought' : FirstBoughtList,
      'Market Value' : MarketValueList,
      '1-Year Return': OneYearReturn,
      'P/E': PEList,
      #  'ESG Risk Rating Assessment' : ESGRiskRatingAssessmentList,
      'Sector': SectorList})
  return Holdings
  driver.close()



def get_mf_holdings(ticker):
  sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
  options = webdriver.ChromeOptions()
  options.add_argument('--headless')
  options.add_argument('--no-sandbox')
  options.add_argument('--disable-dev-shm-usage')
  driver = webdriver.Chrome('chromedriver',options=options)
  driver.get(f'https://www.morningstar.com/funds/xnas/{ticker}/portfolio')

  BackwardButton = driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[2]/div/div/div[1]/div/div[1]/div[2]/div/button[1]''')
  ForwardButton = driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[2]/div/div/div[1]/div/div[1]/div[2]/div/button[2]''')

  CompanyList = []; PortfolioWeightList = []; FirstBoughtList = []; MarketValueList = []; ShareChangeList = []; OneYearReturn = []; PEList = []; SectorList = []; ESGRiskRatingAssessmentList = []

  company = 1
  while company <= 10:
    CompanyList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[1]''').text))
    PortfolioWeightList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[2]''').text))
    FirstBoughtList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[3]''').text))
    MarketValueList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[4]''').text))
    ShareChangeList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[5]''').text).replace('\n',' '))
    OneYearReturn.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[6]''').text))
    PEList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[7]''').text))
    # ESGRiskRatingAssessmentList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[10]''').text))
    SectorList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[11]''').text))
    company += 1
  ForwardButton.click()

  company = 1
  while company <= 10:
    CompanyList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[1]''').text))
    PortfolioWeightList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[2]''').text))
    FirstBoughtList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[3]''').text))
    MarketValueList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[4]''').text))
    ShareChangeList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[5]''').text).replace('\n',' '))
    OneYearReturn.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[6]''').text))
    PEList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[7]''').text))
    # ESGRiskRatingAssessmentList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[10]''').text))
    SectorList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[11]''').text))
    company += 1
  ForwardButton.click()

  company = 1
  while company <= 5:
    CompanyList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[1]''').text))
    PortfolioWeightList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[2]''').text))
    FirstBoughtList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[3]''').text))
    MarketValueList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[4]''').text))
    ShareChangeList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[5]''').text).replace('\n',' '))
    OneYearReturn.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[6]''').text))
    PEList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[7]''').text))
    # ESGRiskRatingAssessmentList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[10]''').text))
    SectorList.append(str(driver.find_element(by=By.XPATH, value = f'''//*[@id="__layout"]/div/div/div[2]/div[3]/div/main/div[2]/div/div/div[1]/sal-components/div/sal-components-funds-portfolio/div/div[3]/div/div/div/div[2]/div[2]/div[1]/div[1]/table/tbody/tr[{company}]/td[11]''').text))
    company += 1

  Holdings = pd.DataFrame(
      {'Holdings': CompanyList,
      '% Portfolio Weight': PortfolioWeightList,
      'First Bought' : FirstBoughtList,
      'Market Value' : MarketValueList,
      'Share Change %' : ShareChangeList,
      '1-Year Return': OneYearReturn,
      'P/E': PEList,
      #  'ESG Risk Rating Assessment' : ESGRiskRatingAssessmentList,
      'Sector': SectorList})
  return Holdings
  driver.close()



def get_holdings(ticker):
    try:
        Holdings = get_etf_holdings(ticker)
    except:
        Holdings = get_mf_holdings(ticker)
    return Holdings

# %% [markdown]
# **Example: ETF**

# %%
get_holdings('IVV')
# Out:
#                           Holdings % Portfolio Weight  First Bought  \
# 0                        Apple Inc               6.57  May 31, 2001
# 1                   Microsoft Corp               5.97  May 31, 2001
# 2                   Amazon.com Inc               2.99  Nov 30, 2005
# 3             Alphabet Inc Class A               2.11  Aug 26, 2019
# 4             Alphabet Inc Class C               1.94  Apr 03, 2014
# 5                        Tesla Inc               1.88  Dec 18, 2020
# 6   Berkshire Hathaway Inc Class B               1.55  Feb 16, 2010
# 7                Johnson & Johnson               1.43  May 31, 2001
# 8           UnitedHealth Group Inc               1.42  May 31, 2001
# 9                      NVIDIA Corp               1.30  Dec 31, 2001
# 10                Exxon Mobil Corp               1.21  May 31, 2001
# 11      Meta Platforms Inc Class A               1.13  Dec 23, 2013
# 12             JPMorgan Chase & Co               1.07  May 31, 2001
# ...

# %% [markdown]
# **Example: Mutual Fund**

# %%
get_holdings('VFIAX')
# Out:
#                           Holdings % Portfolio Weight  First Bought  \
# 0                        Apple Inc               6.57  Jun 30, 1984
# 1                   Microsoft Corp               5.80  May 31, 1994
# 2                   Amazon.com Inc               2.99  Dec 31, 2005
# 3             Alphabet Inc Class A               1.95  Mar 31, 2006
# 4                        Tesla Inc               1.81  Dec 31, 2020
# 5             Alphabet Inc Class C               1.80  Oct 31, 2015
# 6   Berkshire Hathaway Inc Class B               1.65  Mar 31, 2010
# 7                Johnson & Johnson               1.34  Jun 30, 1984
# 8           UnitedHealth Group Inc               1.33  Jun 30, 1994
# 9                      NVIDIA Corp               1.33  Dec 31, 2001
# 10      Meta Platforms Inc Class A               1.27  Dec 31, 2013
# 11                Exxon Mobil Corp               1.16  Dec 31, 1999
# 12             JPMorgan Chase & Co               1.11  Mar 31, 2001
# ...
